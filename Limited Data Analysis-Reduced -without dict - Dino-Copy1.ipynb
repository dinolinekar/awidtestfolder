# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob, os

# %%
#path = r'C:\Users\user\Desktop\BoT-Iot Dataset\Entire Dataset'
path = r'/mnt/data/dino/dataset/'


csvs = "AWID-CLS-R-Trn/1"
csv_paths = os.path.join(path, csvs)
csv_glob = glob.glob(csv_paths)

header_path = os.path.join(path, 'header.csv')
header = pd.read_csv(header_path, header=None)

awid_arr = []
for csv in csv_glob:
    awid_arr.append(
        pd.read_csv(csv, header=None, low_memory=False,
                    names=header.iloc[0]
                   )        
     )
awd = pd.concat(awid_arr)

# %%
awd
# Out:
#          frame.interface_id frame.dlt  frame.offset_shift  frame.time_epoch  \
# 0                         0         ?                 0.0      1.393661e+09
# 1                         0         ?                 0.0      1.393661e+09
# 2                         0         ?                 0.0      1.393661e+09
# 3                         0         ?                 0.0      1.393661e+09
# 4                         0         ?                 0.0      1.393661e+09
# ...                     ...       ...                 ...               ...
# 1795570                   0         ?                 0.0      1.393665e+09
# 1795571                   0         ?                 0.0      1.393665e+09
# 1795572                   0         ?                 0.0      1.393665e+09
# 1795573                   0         ?                 0.0      1.393665e+09
# 1795574                   0         ?                 0.0      1.393665e+09
#
#          frame.time_delta  frame.time_delta_displayed  frame.time_relative  \
# 0                0.000000                    0.000000             0.000000
# 1                0.024271                    0.024271             0.024271
# 2                0.001631                    0.001631             0.025902
# 3                0.055325                    0.055325             0.081227
# 4                0.000415                    0.000415             0.081642
# ...                   ...                         ...                  ...
# 1795570          0.000006                    0.000006          3599.522705
# 1795571          0.005067                    0.005067          3599.527772
# 1795572          0.010242                    0.010242          3599.538014
# 1795573          0.000007                    0.000007          3599.538021
# 1795574          0.033266                    0.033266          3599.571287
#
#          frame.len  frame.cap_len  frame.marked  ...  wlan.qos.priority  \
# 0              261            261             0  ...                  ?
# 1              185            185             0  ...                  ?
# 2              185            185             0  ...                  ?
# 3              159            159             0  ...                  ?
# 4               54             54             0  ...                  ?
# ...            ...            ...           ...  ...                ...
# 1795570         40             40             0  ...                  ?
# 1795571        148            148             0  ...                  ?
# 1795572         54             54             0  ...                  ?
# 1795573         40             40             0  ...                  ?
# 1795574        159            159             0  ...                  ?
#
#          wlan.qos.eosp  wlan.qos.ack  wlan.qos.amsdupresent  \
# 0                    ?             ?                      ?
# 1                    ?             ?                      ?
# 2                    ?             ?                      ?
# 3                    ?             ?                      ?
# 4                    ?             ?                      ?
# ...                ...           ...                    ...
# 1795570              ?             ?                      ?
# 1795571              ?             ?                      ?
# 1795572              ?             ?                      ?
# 1795573              ?             ?                      ?
# 1795574              ?             ?                      ?
#
#          wlan.qos.buf_state_indicated  wlan.qos.bit4  wlan.qos.txop_dur_req  \
# 0                                   ?              ?                      ?
# 1                                   ?              ?                      ?
# 2                                   ?              ?                      ?
# 3                                   ?              ?                      ?
# 4                                   ?              ?                      ?
# ...                               ...            ...                    ...
# 1795570                             ?              ?                      ?
# 1795571                             ?              ?                      ?
# 1795572                             ?              ?                      ?
# 1795573                             ?              ?                      ?
# 1795574                             ?              ?                      ?
#
#          wlan.qos.buf_state_indicated2  data.len   class
# 0                                    ?         ?  normal
# 1                                    ?         ?  normal
# 2                                    ?         ?  normal
# 3                                    ?         ?  normal
# 4                                    ?         ?  normal
# ...                                ...       ...     ...
# 1795570                              ?         ?  normal
# 1795571                              ?         ?  normal
# 1795572                              ?         ?  normal
# 1795573                              ?         ?  normal
# 1795574                              ?         ?  normal
#
# [1795575 rows x 155 columns]

# %%
awd["class"].value_counts()
# Out:
# normal           1633190
# injection          65379
# impersonation      48522
# flooding           48484
# Name: class, dtype: int64

# %% [markdown]
# # Loading Subset of Reduced Dataset

# %%
awid = awd[ (awd['class'] == 'injection') | (awd['class'] == 'normal') ]

# %%
awid["class"].value_counts()
# Out:
# normal       1633190
# injection      65379
# Name: class, dtype: int64

# %%
awid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1698569 entries, 0 to 1795574
# Columns: 155 entries, frame.interface_id to class
# dtypes: float64(6), int64(39), object(110)
# memory usage: 2.0+ GB

# %% [markdown]
# # Replace ? with NaN and Drop NaN values

# %%
#awid.replace({'?':np.nan}).dropna(axis=1,inplace=True)
#awid.super()replace('?',np.nan,inplace=True)

# %%
awid.head()
# Out:
#    frame.interface_id frame.dlt  frame.offset_shift  frame.time_epoch  \
# 0                   0         ?                 0.0      1.393661e+09
# 1                   0         ?                 0.0      1.393661e+09
# 2                   0         ?                 0.0      1.393661e+09
# 3                   0         ?                 0.0      1.393661e+09
# 4                   0         ?                 0.0      1.393661e+09
#
#    frame.time_delta  frame.time_delta_displayed  frame.time_relative  \
# 0          0.000000                    0.000000             0.000000
# 1          0.024271                    0.024271             0.024271
# 2          0.001631                    0.001631             0.025902
# 3          0.055325                    0.055325             0.081227
# 4          0.000415                    0.000415             0.081642
#
#    frame.len  frame.cap_len  frame.marked  ...  wlan.qos.priority  \
# 0        261            261             0  ...                  ?
# 1        185            185             0  ...                  ?
# 2        185            185             0  ...                  ?
# 3        159            159             0  ...                  ?
# 4         54             54             0  ...                  ?
#
#    wlan.qos.eosp  wlan.qos.ack  wlan.qos.amsdupresent  \
# 0              ?             ?                      ?
# 1              ?             ?                      ?
# 2              ?             ?                      ?
# 3              ?             ?                      ?
# 4              ?             ?                      ?
#
#    wlan.qos.buf_state_indicated  wlan.qos.bit4  wlan.qos.txop_dur_req  \
# 0                             ?              ?                      ?
# 1                             ?              ?                      ?
# 2                             ?              ?                      ?
# 3                             ?              ?                      ?
# 4                             ?              ?                      ?
#
#    wlan.qos.buf_state_indicated2  data.len   class
# 0                              ?         ?  normal
# 1                              ?         ?  normal
# 2                              ?         ?  normal
# 3                              ?         ?  normal
# 4                              ?         ?  normal
#
# [5 rows x 155 columns]

# %%
awid=awid.replace('?',np.nan)

# %%
awid.head()
# Out:
#    frame.interface_id  frame.dlt  frame.offset_shift  frame.time_epoch  \
# 0                   0        NaN                 0.0      1.393661e+09
# 1                   0        NaN                 0.0      1.393661e+09
# 2                   0        NaN                 0.0      1.393661e+09
# 3                   0        NaN                 0.0      1.393661e+09
# 4                   0        NaN                 0.0      1.393661e+09
#
#    frame.time_delta  frame.time_delta_displayed  frame.time_relative  \
# 0          0.000000                    0.000000             0.000000
# 1          0.024271                    0.024271             0.024271
# 2          0.001631                    0.001631             0.025902
# 3          0.055325                    0.055325             0.081227
# 4          0.000415                    0.000415             0.081642
#
#    frame.len  frame.cap_len  frame.marked  ...  wlan.qos.priority  \
# 0        261            261             0  ...                NaN
# 1        185            185             0  ...                NaN
# 2        185            185             0  ...                NaN
# 3        159            159             0  ...                NaN
# 4         54             54             0  ...                NaN
#
#    wlan.qos.eosp  wlan.qos.ack  wlan.qos.amsdupresent  \
# 0            NaN           NaN                    NaN
# 1            NaN           NaN                    NaN
# 2            NaN           NaN                    NaN
# 3            NaN           NaN                    NaN
# 4            NaN           NaN                    NaN
#
#    wlan.qos.buf_state_indicated  wlan.qos.bit4  wlan.qos.txop_dur_req  \
# 0                           NaN            NaN                    NaN
# 1                           NaN            NaN                    NaN
# 2                           NaN            NaN                    NaN
# 3                           NaN            NaN                    NaN
# 4                           NaN            NaN                    NaN
#
#    wlan.qos.buf_state_indicated2  data.len   class
# 0                            NaN       NaN  normal
# 1                            NaN       NaN  normal
# 2                            NaN       NaN  normal
# 3                            NaN       NaN  normal
# 4                            NaN       NaN  normal
#
# [5 rows x 155 columns]

# %%
awid=awid.dropna(axis=1)

# %%
awid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1698569 entries, 0 to 1795574
# Data columns (total 49 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   frame.interface_id                  int64
#  1   frame.offset_shift                  float64
#  2   frame.time_epoch                    float64
#  3   frame.time_delta                    float64
#  4   frame.time_delta_displayed          float64
#  5   frame.time_relative                 float64
#  6   frame.len                           int64
#  7   frame.cap_len                       int64
#  8   frame.marked                        int64
#  9   frame.ignored                       int64
#  10  radiotap.version                    int64
#  11  radiotap.pad                        int64
#  12  radiotap.length                     int64
#  13  radiotap.present.tsft               int64
#  14  radiotap.present.flags              int64
#  15  radiotap.present.rate               int64
#  16  radiotap.present.channel            int64
#  17  radiotap.present.fhss               int64
#  18  radiotap.present.dbm_antsignal      int64
#  19  radiotap.present.dbm_antnoise       int64
#  20  radiotap.present.lock_quality       int64
#  21  radiotap.present.tx_attenuation     int64
#  22  radiotap.present.db_tx_attenuation  int64
#  23  radiotap.present.dbm_tx_power       int64
#  24  radiotap.present.antenna            int64
#  25  radiotap.present.db_antsignal       int64
#  26  radiotap.present.db_antnoise        int64
#  27  radiotap.present.rxflags            int64
#  28  radiotap.present.xchannel           int64
#  29  radiotap.present.mcs                int64
#  30  radiotap.present.ampdu              int64
#  31  radiotap.present.vht                int64
#  32  radiotap.present.reserved           object
#  33  radiotap.present.rtap_ns            int64
#  34  radiotap.present.vendor_ns          int64
#  35  radiotap.present.ext                int64
#  36  radiotap.datarate                   float64
#  37  wlan.fc.type_subtype                object
#  38  wlan.fc.version                     int64
#  39  wlan.fc.type                        int64
#  40  wlan.fc.subtype                     int64
#  41  wlan.fc.ds                          object
#  42  wlan.fc.frag                        int64
#  43  wlan.fc.retry                       int64
#  44  wlan.fc.pwrmgt                      int64
#  45  wlan.fc.moredata                    int64
#  46  wlan.fc.protected                   int64
#  47  wlan.fc.order                       int64
#  48  class                               object
# dtypes: float64(6), int64(39), object(4)
# memory usage: 648.0+ MB

# %%
awid.head()
# Out:
#    frame.interface_id  frame.offset_shift  frame.time_epoch  frame.time_delta  \
# 0                   0                 0.0      1.393661e+09          0.000000
# 1                   0                 0.0      1.393661e+09          0.024271
# 2                   0                 0.0      1.393661e+09          0.001631
# 3                   0                 0.0      1.393661e+09          0.055325
# 4                   0                 0.0      1.393661e+09          0.000415
#
#    frame.time_delta_displayed  frame.time_relative  frame.len  frame.cap_len  \
# 0                    0.000000             0.000000        261            261
# 1                    0.024271             0.024271        185            185
# 2                    0.001631             0.025902        185            185
# 3                    0.055325             0.081227        159            159
# 4                    0.000415             0.081642         54             54
#
#    frame.marked  frame.ignored  ...  wlan.fc.type  wlan.fc.subtype  \
# 0             0              0  ...             0                8
# 1             0              0  ...             0                8
# 2             0              0  ...             0                8
# 3             0              0  ...             0                8
# 4             0              0  ...             2                4
#
#    wlan.fc.ds  wlan.fc.frag  wlan.fc.retry  wlan.fc.pwrmgt  wlan.fc.moredata  \
# 0        0x00             0              0               0                 0
# 1        0x00             0              0               0                 0
# 2        0x00             0              0               0                 0
# 3        0x00             0              0               0                 0
# 4        0x01             0              0               0                 0
#
#    wlan.fc.protected  wlan.fc.order   class
# 0                  0              0  normal
# 1                  0              0  normal
# 2                  0              0  normal
# 3                  0              0  normal
# 4                  0              0  normal
#
# [5 rows x 49 columns]

# %%
awid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1698569 entries, 0 to 1795574
# Data columns (total 49 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   frame.interface_id                  int64
#  1   frame.offset_shift                  float64
#  2   frame.time_epoch                    float64
#  3   frame.time_delta                    float64
#  4   frame.time_delta_displayed          float64
#  5   frame.time_relative                 float64
#  6   frame.len                           int64
#  7   frame.cap_len                       int64
#  8   frame.marked                        int64
#  9   frame.ignored                       int64
#  10  radiotap.version                    int64
#  11  radiotap.pad                        int64
#  12  radiotap.length                     int64
#  13  radiotap.present.tsft               int64
#  14  radiotap.present.flags              int64
#  15  radiotap.present.rate               int64
#  16  radiotap.present.channel            int64
#  17  radiotap.present.fhss               int64
#  18  radiotap.present.dbm_antsignal      int64
#  19  radiotap.present.dbm_antnoise       int64
#  20  radiotap.present.lock_quality       int64
#  21  radiotap.present.tx_attenuation     int64
#  22  radiotap.present.db_tx_attenuation  int64
#  23  radiotap.present.dbm_tx_power       int64
#  24  radiotap.present.antenna            int64
#  25  radiotap.present.db_antsignal       int64
#  26  radiotap.present.db_antnoise        int64
#  27  radiotap.present.rxflags            int64
#  28  radiotap.present.xchannel           int64
#  29  radiotap.present.mcs                int64
#  30  radiotap.present.ampdu              int64
#  31  radiotap.present.vht                int64
#  32  radiotap.present.reserved           object
#  33  radiotap.present.rtap_ns            int64
#  34  radiotap.present.vendor_ns          int64
#  35  radiotap.present.ext                int64
#  36  radiotap.datarate                   float64
#  37  wlan.fc.type_subtype                object
#  38  wlan.fc.version                     int64
#  39  wlan.fc.type                        int64
#  40  wlan.fc.subtype                     int64
#  41  wlan.fc.ds                          object
#  42  wlan.fc.frag                        int64
#  43  wlan.fc.retry                       int64
#  44  wlan.fc.pwrmgt                      int64
#  45  wlan.fc.moredata                    int64
#  46  wlan.fc.protected                   int64
#  47  wlan.fc.order                       int64
#  48  class                               object
# dtypes: float64(6), int64(39), object(4)
# memory usage: 648.0+ MB

# %%
awid.loc[ awid['class']=='injection','class' ]=1
awid.loc[ awid['class']=='normal','class' ]=0
awid['class'] = awid['class'].astype(int)

# %%
awid.drop(["radiotap.present.reserved", "wlan.fc.type_subtype", "wlan.fc.ds"], axis=1, inplace=True)

# %%
awid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1698569 entries, 0 to 1795574
# Data columns (total 46 columns):
#  #   Column                              Dtype
# ---  ------                              -----
#  0   frame.interface_id                  int64
#  1   frame.offset_shift                  float64
#  2   frame.time_epoch                    float64
#  3   frame.time_delta                    float64
#  4   frame.time_delta_displayed          float64
#  5   frame.time_relative                 float64
#  6   frame.len                           int64
#  7   frame.cap_len                       int64
#  8   frame.marked                        int64
#  9   frame.ignored                       int64
#  10  radiotap.version                    int64
#  11  radiotap.pad                        int64
#  12  radiotap.length                     int64
#  13  radiotap.present.tsft               int64
#  14  radiotap.present.flags              int64
#  15  radiotap.present.rate               int64
#  16  radiotap.present.channel            int64
#  17  radiotap.present.fhss               int64
#  18  radiotap.present.dbm_antsignal      int64
#  19  radiotap.present.dbm_antnoise       int64
#  20  radiotap.present.lock_quality       int64
#  21  radiotap.present.tx_attenuation     int64
#  22  radiotap.present.db_tx_attenuation  int64
#  23  radiotap.present.dbm_tx_power       int64
#  24  radiotap.present.antenna            int64
#  25  radiotap.present.db_antsignal       int64
#  26  radiotap.present.db_antnoise        int64
#  27  radiotap.present.rxflags            int64
#  28  radiotap.present.xchannel           int64
#  29  radiotap.present.mcs                int64
#  30  radiotap.present.ampdu              int64
#  31  radiotap.present.vht                int64
#  32  radiotap.present.rtap_ns            int64
#  33  radiotap.present.vendor_ns          int64
#  34  radiotap.present.ext                int64
#  35  radiotap.datarate                   float64
#  36  wlan.fc.version                     int64
#  37  wlan.fc.type                        int64
#  38  wlan.fc.subtype                     int64
#  39  wlan.fc.frag                        int64
#  40  wlan.fc.retry                       int64
#  41  wlan.fc.pwrmgt                      int64
#  42  wlan.fc.moredata                    int64
#  43  wlan.fc.protected                   int64
#  44  wlan.fc.order                       int64
#  45  class                               int64
# dtypes: float64(6), int64(40)
# memory usage: 609.1 MB

# %%
awid['class'].value_counts()
# Out:
# 0    1633190
# 1      65379
# Name: class, dtype: int64

# %% [markdown]
# # Sep features and target columns

# %%
X = awid.drop( ["class"], axis=1)

y = awid["class"]

# %% [markdown]
# # Train and Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Modeling

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
clf.score(X_test, y_test)
# Out:
# 0.9754856135643536

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
y_preds = clf.predict(X_test)

# %%
print( classification_report(y_test, y_preds) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99    539221
#            1       0.68      0.67      0.68     21307
#
#     accuracy                           0.98    560528
#    macro avg       0.83      0.83      0.83    560528
# weighted avg       0.98      0.98      0.98    560528

# %%
conf_mat = confusion_matrix(y_test, y_preds)
conf_mat
# Out:
# array([[532496,   6725],
#        [  7016,  14291]])

# %% [markdown]
# # Loop

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import train_test_split

# %%
CLF = {
    'KNN': KNeighborsClassifier(),
    'RFR': RandomForestClassifier(random_state=42),
    'LRE': LogisticRegression(),
}

def model( df ):

    for cl in CLF:
        print('ClASSIFIER :',cl)
        clf = CLF[cl]

        X = awid.drop( ["class"], axis=1)
        y = awid["class"]
        
        X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.33, random_state=42)

        clf.fit(X_train, y_train)
        print('score = ',clf.score(X_test, y_test))
        y_preds = clf.predict(X_test)
        print( classification_report(y_test, y_preds) )
        print( confusion_matrix(y_test, y_preds))
        print('')
        print('========')
    print('')
    print('=============================')
    print('')

# %%
#for cat in awid:
    print('============',cat,'============')
    df=awid
    model(df)
