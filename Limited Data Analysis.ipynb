# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob, os

# %%
#path = r'C:\Users\user\Desktop\BoT-Iot Dataset\Entire Dataset'
path = r'/mnt/data/dino/dataset/'


csvs = "AWID-CLS-F-Trn/56"
csv_paths = os.path.join(path, csvs)
csv_glob = glob.glob(csv_paths)

header_path = os.path.join(path, 'header.csv')
header = pd.read_csv(header_path, header=None)

awid_arr = []
for csv in csv_glob:
    awid_arr.append(
        pd.read_csv(csv, header=None, low_memory=False,
                    names=header.iloc[0]
                   )        
     )
awid = pd.concat(awid_arr)

# %%
awid
# Out:
#         frame.interface_id frame.dlt  frame.offset_shift  frame.time_epoch  \
# 0                        0         ?                 0.0      1.424840e+09
# 1                        0         ?                 0.0      1.424840e+09
# 2                        0         ?                 0.0      1.424840e+09
# 3                        0         ?                 0.0      1.424840e+09
# 4                        0         ?                 0.0      1.424840e+09
# ...                    ...       ...                 ...               ...
# 467257                   0         ?                 0.0      1.424844e+09
# 467258                   0         ?                 0.0      1.424844e+09
# 467259                   0         ?                 0.0      1.424844e+09
# 467260                   0         ?                 0.0      1.424844e+09
# 467261                   0         ?                 0.0      1.424844e+09
#
#         frame.time_delta  frame.time_delta_displayed  frame.time_relative  \
# 0               0.000000                    0.000000             0.000000
# 1               0.004427                    0.004427             0.004427
# 2               0.009860                    0.009860             0.014287
# 3               0.000021                    0.000021             0.014308
# 4               0.001152                    0.001152             0.015460
# ...                  ...                         ...                  ...
# 467257          0.030306                    0.030306           599.955140
# 467258          0.016502                    0.016502           599.971642
# 467259          0.020562                    0.020562           599.992204
# 467260          0.005744                    0.005744           599.997948
# 467261          0.059595                    0.059595           600.057543
#
#         frame.len  frame.cap_len  frame.marked  ...  wlan.qos.priority  \
# 0              70             70             0  ...                  ?
# 1             367            367             0  ...                  ?
# 2              58             58             0  ...                  ?
# 3              52             52             0  ...                  ?
# 4              58             58             0  ...                  ?
# ...           ...            ...           ...  ...                ...
# 467257        334            334             0  ...                  ?
# 467258        271            271             0  ...                  ?
# 467259        367            367             0  ...                  ?
# 467260        160            160             0  ...                  ?
# 467261        334            334             0  ...                  ?
#
#         wlan.qos.eosp  wlan.qos.ack  wlan.qos.amsdupresent  \
# 0                   ?             ?                      ?
# 1                   ?             ?                      ?
# 2                   ?             ?                      ?
# 3                   ?             ?                      ?
# 4                   ?             ?                      ?
# ...               ...           ...                    ...
# 467257              ?             ?                      ?
# 467258              ?             ?                      ?
# 467259              ?             ?                      ?
# 467260              ?             ?                      ?
# 467261              ?             ?                      ?
#
#         wlan.qos.buf_state_indicated  wlan.qos.bit4  wlan.qos.txop_dur_req  \
# 0                                  ?              ?                      ?
# 1                                  ?              ?                      ?
# 2                                  ?              ?                      ?
# 3                                  ?              ?                      ?
# 4                                  ?              ?                      ?
# ...                              ...            ...                    ...
# 467257                             ?              ?                      ?
# 467258                             ?              ?                      ?
# 467259                             ?              ?                      ?
# 467260                             ?              ?                      ?
# 467261                             ?              ?                      ?
#
#         wlan.qos.buf_state_indicated2  data.len   class
# 0                                   ?         ?  normal
# 1                                   ?         ?  normal
# 2                                   ?         ?  normal
# 3                                   ?         ?  normal
# 4                                   ?         ?  normal
# ...                               ...       ...     ...
# 467257                              ?         ?  normal
# 467258                              ?         ?  normal
# 467259                              ?         ?  normal
# 467260                              ?         ?  normal
# 467261                              ?         ?  normal
#
# [467262 rows x 155 columns]

# %%
awid['wlan.qos.buf_state_indicated'].value_counts()
# Out:
# ?    203789
# Name: wlan.qos.buf_state_indicated, dtype: int64

# %%
awid["class"].value_counts()
# Out:
# normal    203789
# Name: class, dtype: int64

# %%
awid["category"].value_counts()

# %%
attack = awid[awid['attack'] == 1][:1000]
attack.shape

# %%
benign = awid[awid['attack'] == 0][:10000]
benign.shape

# %%
awid["attack"].value_counts()
